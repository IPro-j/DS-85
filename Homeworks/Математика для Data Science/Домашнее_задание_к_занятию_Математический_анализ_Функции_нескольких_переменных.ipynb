# %%
'''
Задание 1
Посчитайте частные производные функций

2𝑥2𝑦3+𝑥𝑦2+7+1𝑥

𝑥2𝑦+6𝑦−sin(𝑥𝑦)+cos(𝑥2)
'''

from sympy import *

x,y = symbols('x y')

# %%
f = 2*x**2*y**3 + 1/x + y**2*x + 7
f
# Out:
# 2*x**2*y**3 + x*y**2 + 7 + 1/x

# %%
f_diff_x = diff(f, x)
f_diff_x
# Out:
# 4*x*y**3 + y**2 - 1/x**2

# %%
f_diff_y = diff(f, y)
f_diff_y
# Out:
# 6*x**2*y**2 + 2*x*y

# %%
f1 = x**2*y - sin(x*y) + cos(x**2) + 6*y
f1
# Out:
# x**2*y + 6*y - sin(x*y) + cos(x**2)

# %%
diff(f1, x)
# Out:
# 2*x*y - 2*x*sin(x**2) - y*cos(x*y)

# %%
diff(f1, y)
# Out:
# x**2 - x*cos(x*y) + 6

# %%
'''
Задание 2
Вычислите градиент функции:

2𝑥2𝑦3+𝑥𝑦2+7+1𝑥

в точке 1,2
'''

grad = [diff(f,var) for var in (x,y)]
grad_ = lambdify([x,y], grad)

grad_(1, 2)
# Out:
# [35.0, 28]

# %%
'''
Постройте трехмерный график функции

−𝑥21𝑥2+2𝑥1𝑥2+𝑥22
'''


from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

# %%
def fun(x_1, x_2):
    return x_2**2 - x_2*x_1**2 + 2*x_1*x_2
# Out:
# 9

# %%
x1_ = np.linspace(-5, 5, 100)
x2_ = x1_

z = fun(x1_, x1_)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot(x1_, x2_, z, label='parametric curve')
